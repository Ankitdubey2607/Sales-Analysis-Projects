# %%
import pandas as  pd

# %%
 df = pd.read_csv(r'C:\Users\imadu\Documents\Database1.csv', encoding='latin-1')
# Out:
# C:\Users\imadu\AppData\Local\Temp\ipykernel_13976\590850658.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\imadu\Documents\Database1.csv', encoding='latin-1')

# %%
df
# Out:
#         OrderDate  idProduct  \
# 0      01-01-2017        348
# 1      01-01-2017        293
# 2      01-01-2017        394
# 3      01-01-2017        458
# 4      01-01-2017        431
# ...           ...        ...
# 70050  16-03-2019         36
# 70051  16-03-2019         22
# 70052  16-03-2019         80
# 70053  16-03-2019         58
# 70054  16-03-2019         56
#
#                                                  Product  \
# 0                       Fabrikam Laptop15.4W M5480 White
# 1                         SV Car Video LCD7W M7081 Black
# 2                            WWI Laptop15.4W M0156 Black
# 3                         WWI Desktop PC1.80 E1800 White
# 4             Adventure Works Desktop PC1.80 ED180 Brown
# ...                                                  ...
# 70050        Contoso 4GB Portable MP3 Player M450 Yellow
# 70051       Contoso 8GB MP3 Player new model M820 Yellow
# 70052  NT Wireless Bluetooth Stereo Headphones E302 Y...
# ...

# %%
df.isnull().sum()
# Out:
# OrderDate             0
# idProduct             0
# Product               0
# Brand                 0
# idCustomer            0
# Customer          52034
# Continent             0
# Country               0
# State                 0
# City                  0
# OrderNumber           0
# UnitCost              0
# UnitPrice             0
# Quantity              0
# DiscountAmount        0
# dtype: int64

# %%
df.count()
# Out:
# OrderDate         70055
# idProduct         70055
# Product           70055
# Brand             70055
# idCustomer        70055
# Customer          18021
# Continent         70055
# Country           70055
# State             70055
# City              70055
# OrderNumber       70055
# UnitCost          70055
# UnitPrice         70055
# Quantity          70055
# DiscountAmount    70055
# dtype: int64

# %%
df.drop(['Customer'], axis=1, inplace=True)

# %%
df
# Out:
#         OrderDate  idProduct  \
# 0      01-01-2017        348
# 1      01-01-2017        293
# 2      01-01-2017        394
# 3      01-01-2017        458
# 4      01-01-2017        431
# ...           ...        ...
# 70050  16-03-2019         36
# 70051  16-03-2019         22
# 70052  16-03-2019         80
# 70053  16-03-2019         58
# 70054  16-03-2019         56
#
#                                                  Product  \
# 0                       Fabrikam Laptop15.4W M5480 White
# 1                         SV Car Video LCD7W M7081 Black
# 2                            WWI Laptop15.4W M0156 Black
# 3                         WWI Desktop PC1.80 E1800 White
# 4             Adventure Works Desktop PC1.80 ED180 Brown
# ...                                                  ...
# 70050        Contoso 4GB Portable MP3 Player M450 Yellow
# 70051       Contoso 8GB MP3 Player new model M820 Yellow
# 70052  NT Wireless Bluetooth Stereo Headphones E302 Y...
# ...

# %%
df['Country'].nunique()
# Out:
# 14

# %%
df['OrderNumber'].nunique()
# Out:
# 9804

# %%
df.drop(['idProduct', 'OrderDate'], axis=1, inplace=True)

# %%
df
# Out:
#                                                  Product  \
# 0                       Fabrikam Laptop15.4W M5480 White
# 1                         SV Car Video LCD7W M7081 Black
# 2                            WWI Laptop15.4W M0156 Black
# 3                         WWI Desktop PC1.80 E1800 White
# 4             Adventure Works Desktop PC1.80 ED180 Brown
# ...                                                  ...
# 70050        Contoso 4GB Portable MP3 Player M450 Yellow
# 70051       Contoso 8GB MP3 Player new model M820 Yellow
# 70052  NT Wireless Bluetooth Stereo Headphones E302 Y...
# 70053        WWI 1GB Digital Voice Recorder Pen E100 Red
# 70054            WWI 4GB Video Recording Pen X200 Yellow
#
#                       Brand  idCustomer      Continent        Country  \
# 0                  Fabrikam       19079           Asia      Australia
# 1          Southridge Video       19079           Asia      Australia
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df['City'].nunique()
# Out:
# 318

# %%
df.head()
# Out:
#                                       Product                 Brand  \
# 0            Fabrikam Laptop15.4W M5480 White              Fabrikam
# 1              SV Car Video LCD7W M7081 Black      Southridge Video
# 2                 WWI Laptop15.4W M0156 Black  Wide World Importers
# 3              WWI Desktop PC1.80 E1800 White  Wide World Importers
# 4  Adventure Works Desktop PC1.80 ED180 Brown       Adventure Works
#
#    idCustomer Continent    Country     State     City     OrderNumber  \
# 0       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 1       19079      Asia  Australia  Victoria  Bendigo  200701012CS425
# 2       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 3       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 4       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
#
#    UnitCost  UnitPrice  Quantity  DiscountAmount
# 0    348.58      758.0        14         1591.80
# ...

# %%
max_city=df.groupby(['City'], as_index=False)['Quantity'].max().sort_values(by='Quantity', ascending=False).head(10)

# %%
max_city
# Out:
#                City  Quantity
# 244        Puyallup       118
# 60   Campbellsville       108
# 27           Berlin       108
# 232       Palo Alto        93
# 263      San Carlos        93
# 242    Port Orchard        93
# 73        Charlotte        90
# 86        Cliffside        87
# 248          Renton        75
# 250     Rockhampton        74

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x='City', y = 'Quantity', data=max_city)
# Out:
# <Axes: xlabel='City', ylabel='Quantity'>

# %%
continent_city = df.groupby(['Continent'])['City'].count().reset_index()
sns.set(rc={'figure.figsize':(12,8)})
sns.barplot(y='City', x='Continent', data=continent_city)
# Out:
# <Axes: xlabel='Continent', ylabel='City'>

# %%
df
# Out:
#                                                  Product  \
# 0                       Fabrikam Laptop15.4W M5480 White
# 1                         SV Car Video LCD7W M7081 Black
# 2                            WWI Laptop15.4W M0156 Black
# 3                         WWI Desktop PC1.80 E1800 White
# 4             Adventure Works Desktop PC1.80 ED180 Brown
# ...                                                  ...
# 70050        Contoso 4GB Portable MP3 Player M450 Yellow
# 70051       Contoso 8GB MP3 Player new model M820 Yellow
# 70052  NT Wireless Bluetooth Stereo Headphones E302 Y...
# 70053        WWI 1GB Digital Voice Recorder Pen E100 Red
# 70054            WWI 4GB Video Recording Pen X200 Yellow
#
#                       Brand  idCustomer      Continent        Country  \
# 0                  Fabrikam       19079           Asia      Australia
# 1          Southridge Video       19079           Asia      Australia
# ...

# %%
# Assuming df is your DataFrame
df['Total Amount'] = df['UnitPrice'] * df['Quantity'] - df['DiscountAmount']

# %%
df = pd.DataFrame(df)

# %%
df['idCustomer'].nunique()
# Out:
# 7655

# %%
df
# Out:
#                                                  Product  \
# 0                       Fabrikam Laptop15.4W M5480 White
# 1                         SV Car Video LCD7W M7081 Black
# 2                            WWI Laptop15.4W M0156 Black
# 3                         WWI Desktop PC1.80 E1800 White
# 4             Adventure Works Desktop PC1.80 ED180 Brown
# ...                                                  ...
# 70050        Contoso 4GB Portable MP3 Player M450 Yellow
# 70051       Contoso 8GB MP3 Player new model M820 Yellow
# 70052  NT Wireless Bluetooth Stereo Headphones E302 Y...
# 70053        WWI 1GB Digital Voice Recorder Pen E100 Red
# 70054            WWI 4GB Video Recording Pen X200 Yellow
#
#                       Brand  idCustomer      Continent        Country  \
# 0                  Fabrikam       19079           Asia      Australia
# 1          Southridge Video       19079           Asia      Australia
# ...

# %%
country_amount=df.groupby(['Country'], as_index=False)['Total Amount'].sum().sort_values(by='Total Amount', ascending=False).head(10)

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.barplot(x="Country", y='Total Amount', data=country_amount)
# Out:
# <Axes: xlabel='Country', ylabel='Total Amount'>

# %%
grouped_df=df.groupby(['Country', 'Product'], as_index=False)['Total Amount'].sum().sort_values(by='Total Amount', ascending=False)
top_10_product=grouped_df.groupby('Product')['Total Amount'].sum().nlargest(10).index
top_10_country=grouped_df.groupby('Country')['Total Amount'].sum().nlargest(10).index
filtered_df=grouped_df[(grouped_df['Product'].isin(top_10_product))&(grouped_df['Country'].isin(top_10_country))]
filtered_df=filtered_df.sort_values(by=['Product', 'Total Amount'], ascending=[True, False])

# %%
sns.barplot(x='Country', y='Total Amount', data=filtered_df)
# Out:
# <Axes: xlabel='Country', ylabel='Total Amount'>

# %% [markdown]
#  The top 10 products in terms of total amount, categorized by the top 10 countries with the maximum total amount.

# %%
sns.set(rc={'figure.figsize':(16,8)})
sns.barplot(x='Product', y='Total Amount', data=filtered_df)
# Out:
# <Axes: xlabel='Product', ylabel='Total Amount'>

# %%
df.head()
# Out:
#                                       Product                 Brand  \
# 0            Fabrikam Laptop15.4W M5480 White              Fabrikam
# 1              SV Car Video LCD7W M7081 Black      Southridge Video
# 2                 WWI Laptop15.4W M0156 Black  Wide World Importers
# 3              WWI Desktop PC1.80 E1800 White  Wide World Importers
# 4  Adventure Works Desktop PC1.80 ED180 Brown       Adventure Works
#
#    idCustomer Continent    Country     State     City     OrderNumber  \
# 0       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 1       19079      Asia  Australia  Victoria  Bendigo  200701012CS425
# 2       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 3       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 4       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
#
#    UnitCost  UnitPrice  Quantity  DiscountAmount  Total Amount
# 0    348.58      758.0        14         1591.80       9020.20
# ...

# %%
Brand_df=df.groupby(['Brand'], as_index=False)['Total Amount'].sum().sort_values(by='Total Amount', ascending=False)
sns.barplot(x='Brand', y='Total Amount', data=Brand_df)
# Out:
# <Axes: xlabel='Brand', ylabel='Total Amount'>

# %% [markdown]
# Adventure Works has a maximum Total Amount and Northwind Traders has minimum Total Amount.

# %%
Brand_unitprice=df.groupby(['Brand'], as_index=False)['UnitPrice'].min().sort_values(by='UnitPrice', ascending=False)
sns.barplot(x='Brand', y='UnitPrice', data=Brand_unitprice)
# Out:
# <Axes: xlabel='Brand', ylabel='UnitPrice'>

# %% [markdown]
# So Brand Fabrikam has a highest unit price while Contoso has least unit price.

# %%
Brand_quantity=df.groupby(['Brand'], as_index=False)['Quantity'].sum().sort_values(by='Quantity', ascending=False)
sns.barplot(x='Brand', y='Quantity', data=Brand_quantity)
# Out:
# <Axes: xlabel='Brand', ylabel='Quantity'>

# %% [markdown]
# Adventure Works has ordered maximum quantity & Litware ordered minimum quantity.

# %%
df.head()
# Out:
#                                       Product                 Brand  \
# 0            Fabrikam Laptop15.4W M5480 White              Fabrikam
# 1              SV Car Video LCD7W M7081 Black      Southridge Video
# 2                 WWI Laptop15.4W M0156 Black  Wide World Importers
# 3              WWI Desktop PC1.80 E1800 White  Wide World Importers
# 4  Adventure Works Desktop PC1.80 ED180 Brown       Adventure Works
#
#    idCustomer Continent    Country     State     City     OrderNumber  \
# 0       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 1       19079      Asia  Australia  Victoria  Bendigo  200701012CS425
# 2       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 3       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 4       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
#
#    UnitCost  UnitPrice  Quantity  DiscountAmount  Total Amount
# 0    348.58      758.0        14         1591.80       9020.20
# ...

# %%
# Group by 'Brand' and 'City', then count occurrences
grouped = df.groupby(['Brand', 'City']).size().reset_index(name='Count')
top_cities_per_brand = grouped.sort_values(['Brand', 'Count'], ascending=[True, False]).groupby('Brand').head(10)

print(top_cities_per_brand)
# Out:
#                      Brand           City  Count
# 19         Adventure Works         Berlin    844
# 84         Adventure Works        Hamburg    478
# 58         Adventure Works  Coffs Harbour    295
# 89         Adventure Works           Kiel    269
# 101        Adventure Works     Matraville    261
# ...                    ...            ...    ...
# 1393  Wide World Importers           Kiel    174
# 1352  Wide World Importers  Coffs Harbour    173
# 1333  Wide World Importers      Cambridge    172
# 1418  Wide World Importers          Paris    171
# 1395  Wide World Importers      Lancaster    161
#
# [80 rows x 3 columns]

# %%
sns.barplot(x='City', y='Count', data=
            top_cities_per_brand[top_cities_per_brand['Brand']== 'Adventure Works'])
plt.title('Top 10 City Brand Adventure Works')
# Out:
# Text(0.5, 1.0, 'Top 10 City Brand Adventure Works')

# %%
df['Brand'].unique()
# Out:
# array(['Fabrikam', 'Southridge Video', 'Wide World Importers',
#        'Adventure Works', 'Proseware', 'Contoso', 'Northwind Traders',
#        'Litware'], dtype=object)

# %%
sns.barplot(x='City', y='Count', data=
            top_cities_per_brand[top_cities_per_brand['Brand']== 'Fabrikam'])
plt.title('Top 10 City Brand Fabrikam')
# Out:
# Text(0.5, 1.0, 'Top 10 City Brand Fabrikam')

# %%
sns.barplot(x='City', y='Count', data=
            top_cities_per_brand[top_cities_per_brand['Brand']== 'Southridge Video'])
plt.title('Top 10 City Brand Southridge Video')
# Out:
# Text(0.5, 1.0, 'Top 10 City Brand Southridge Video')

# %%
sns.barplot(x='City', y='Count', data=
            top_cities_per_brand[top_cities_per_brand['Brand']== 'Wide World Importers'])
plt.title('Top 10 City Brand Wide World Importers')
# Out:
# Text(0.5, 1.0, 'Top 10 City Brand Wide World Importers')

# %%
sns.barplot(x='City', y='Count', data=
            top_cities_per_brand[top_cities_per_brand['Brand']== 'Proseware'])
plt.title('Top 10 City Brand Proseware')
# Out:
# Text(0.5, 1.0, 'Top 10 City Brand Proseware')

# %%
sns.barplot(x='City', y='Count', data=
            top_cities_per_brand[top_cities_per_brand['Brand']== 'Contoso'])
plt.title('Top 10 City Brand Contoso')
# Out:
# Text(0.5, 1.0, 'Top 10 City Brand Contoso')

# %%
sns.barplot(x='City', y='Count', data=
            top_cities_per_brand[top_cities_per_brand['Brand']== 'Northwind Traders'])
plt.title('Top 10 City Brand Northwind Traders')
# Out:
# Text(0.5, 1.0, 'Top 10 City Brand Northwind Traders')

# %%
sns.barplot(x='City', y='Count', data=
            top_cities_per_brand[top_cities_per_brand['Brand']== 'Litware'])
plt.title('Top 10 City Brand Litware')
# Out:
# Text(0.5, 1.0, 'Top 10 City Brand Litware')

# %%
df.head()
# Out:
#                                       Product                 Brand  \
# 0            Fabrikam Laptop15.4W M5480 White              Fabrikam
# 1              SV Car Video LCD7W M7081 Black      Southridge Video
# 2                 WWI Laptop15.4W M0156 Black  Wide World Importers
# 3              WWI Desktop PC1.80 E1800 White  Wide World Importers
# 4  Adventure Works Desktop PC1.80 ED180 Brown       Adventure Works
#
#    idCustomer Continent    Country     State     City     OrderNumber  \
# 0       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 1       19079      Asia  Australia  Victoria  Bendigo  200701012CS425
# 2       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 3       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 4       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
#
#    UnitCost  UnitPrice  Quantity  DiscountAmount  Total Amount
# 0    348.58      758.0        14         1591.80       9020.20
# ...

# %%
product_brand_df=df.groupby('Brand')['Product'].count().reset_index(name='count')
sns.barplot(x='Brand', y='count', data=product_brand_df)
plt.title('No of Product Vs Brand')
# Out:
# Text(0.5, 1.0, 'No of Product Vs Brand')

# %% [markdown]
# Maximum number of product fall on Northwind Traders brand, while minimum number of product in Litware brand.

# %%
df.head()
# Out:
#                                       Product                 Brand  \
# 0            Fabrikam Laptop15.4W M5480 White              Fabrikam
# 1              SV Car Video LCD7W M7081 Black      Southridge Video
# 2                 WWI Laptop15.4W M0156 Black  Wide World Importers
# 3              WWI Desktop PC1.80 E1800 White  Wide World Importers
# 4  Adventure Works Desktop PC1.80 ED180 Brown       Adventure Works
#
#    idCustomer Continent    Country     State     City     OrderNumber  \
# 0       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 1       19079      Asia  Australia  Victoria  Bendigo  200701012CS425
# 2       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 3       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
# 4       19079      Asia  Australia  Victoria  Bendigo  200701013CS425
#
#    UnitCost  UnitPrice  Quantity  DiscountAmount  Total Amount
# 0    348.58      758.0        14         1591.80       9020.20
# ...

# %% [markdown]
# Project Summary

# %% [markdown]
# Max city cover in europe continent followed by north america.
# Australia has collected max revenue as Total Amount followed by united states.
# The top 10 products in terms of total amount, categorized by the top 10 countries with the maximum total amount.
# Adventure Works Brand has collected maximum revenue and Northwind traders has minimum revenue.
# Fabrikam has maximum UnitPrice and Contoso has minimum UnitPrice.
# Adventure Works has ordered maximum quantity & Litware ordered minimum quantity.
# Maximum number of product fall on Northwind Traders brand, while minimum number of product in Litware brand.
